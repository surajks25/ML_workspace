# %% [markdown]
# <a href="https://colab.research.google.com/github/surajks25/ML_workspace/blob/main/data_splitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#data splitting
#upload dataset
#manual split
#split using skleran.model_selection

# %%
import pandas as pd

df = pd.read_csv("/content/Iris.csv", header=None)

df.columns = ["Id", "sl", "sw", "pl", "pw", "labels"]

df = df.drop("Id", axis=1)

df.head()
# Out:
#               sl            sw             pl            pw       labels
# 0  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1            5.1           3.5            1.4           0.2  Iris-setosa
# 2            4.9           3.0            1.4           0.2  Iris-setosa
# 3            4.7           3.2            1.3           0.2  Iris-setosa
# 4            4.6           3.1            1.5           0.2  Iris-setosa

# %%
df = df.drop(index=0) #y we delete row coz we match the totorial data

# %%
df
# Out:
#       sl   sw   pl   pw          labels
# 1    5.1  3.5  1.4  0.2     Iris-setosa
# 2    4.9  3.0  1.4  0.2     Iris-setosa
# 3    4.7  3.2  1.3  0.2     Iris-setosa
# 4    4.6  3.1  1.5  0.2     Iris-setosa
# 5    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 146  6.7  3.0  5.2  2.3  Iris-virginica
# 147  6.3  2.5  5.0  1.9  Iris-virginica
# 148  6.5  3.0  5.2  2.0  Iris-virginica
# 149  6.2  3.4  5.4  2.3  Iris-virginica
# 150  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#practise rename the column value
# df = df.rename(columns={
#     "SepalLengthCm": "sl",
#     "SepalWidthCm": "sw",
#     "PetalLengthCm": "pl",
#     "PetalWidthCm": "pw",
#     "Species": "labels"
# })

# %%
#drop null value
df = df.dropna(inplace=True)
#this code will delete the hole df valriabel value so we need to rework on the data

# %%
import pandas as pd
df = pd.read_csv("/content/Iris.csv", header=None)
df.columns = ["Id", "sl", "sw", "pl", "pw", "labels"]
df = df.drop("Id", axis=1)
df = df.drop(index=0)
df.head()
# Out:
#     sl   sw   pl   pw       labels
# 1  5.1  3.5  1.4  0.2  Iris-setosa
# 2  4.9  3.0  1.4  0.2  Iris-setosa
# 3  4.7  3.2  1.3  0.2  Iris-setosa
# 4  4.6  3.1  1.5  0.2  Iris-setosa
# 5  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.isnull().sum()
# Out:
# sl        0
# sw        0
# pl        0
# pw        0
# labels    0
# dtype: int64

# %%
# this is remove only the null value all position df.dropna(inplace=True)
#dont use like this df = df.dropna(inplace=True) this will delete the all value inside the df variable

# %%
# 1 make manual spliting
#input = x
#output = y

# %%
x = df.iloc[:,:4]

# %%
x
# Out:
#       sl   sw   pl   pw
# 1    5.1  3.5  1.4  0.2
# 2    4.9  3.0  1.4  0.2
# 3    4.7  3.2  1.3  0.2
# 4    4.6  3.1  1.5  0.2
# 5    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 146  6.7  3.0  5.2  2.3
# 147  6.3  2.5  5.0  1.9
# 148  6.5  3.0  5.2  2.0
# 149  6.2  3.4  5.4  2.3
# 150  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
y = df.iloc[:,4]

# %%
y
# Out:
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
#             ...
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# 150    Iris-virginica
# Name: labels, Length: 150, dtype: object

# %%
#training and testing
x_train = x.iloc[:100]

# %%
x_test = x.iloc[100:]

# %%
x_train
# Out:
#       sl   sw   pl   pw
# 1    5.1  3.5  1.4  0.2
# 2    4.9  3.0  1.4  0.2
# 3    4.7  3.2  1.3  0.2
# 4    4.6  3.1  1.5  0.2
# 5    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 96   5.7  3.0  4.2  1.2
# 97   5.7  2.9  4.2  1.3
# 98   6.2  2.9  4.3  1.3
# 99   5.1  2.5  3.0  1.1
# 100  5.7  2.8  4.1  1.3
#
# [100 rows x 4 columns]

# %%
x_test
# Out:
#       sl   sw   pl   pw
# 101  6.3  3.3  6.0  2.5
# 102  5.8  2.7  5.1  1.9
# 103  7.1  3.0  5.9  2.1
# 104  6.3  2.9  5.6  1.8
# 105  6.5  3.0  5.8  2.2
# 106  7.6  3.0  6.6  2.1
# 107  4.9  2.5  4.5  1.7
# 108  7.3  2.9  6.3  1.8
# 109  6.7  2.5  5.8  1.8
# 110  7.2  3.6  6.1  2.5
# 111  6.5  3.2  5.1  2.0
# 112  6.4  2.7  5.3  1.9
# 113  6.8  3.0  5.5  2.1
# 114  5.7  2.5  5.0  2.0
# 115  5.8  2.8  5.1  2.4
# 116  6.4  3.2  5.3  2.3
# 117  6.5  3.0  5.5  1.8
# 118  7.7  3.8  6.7  2.2
# 119  7.7  2.6  6.9  2.3
# 120  6.0  2.2  5.0  1.5
# 121  6.9  3.2  5.7  2.3
# 122  5.6  2.8  4.9  2.0
# 123  7.7  2.8  6.7  2.0
# 124  6.3  2.7  4.9  1.8
# 125  6.7  3.3  5.7  2.1
# 126  7.2  3.2  6.0  1.8
# 127  6.2  2.8  4.8  1.8
# 128  6.1  3.0  4.9  1.8
# 129  6.4  2.8  5.6  2.1
# 130  7.2  3.0  5.8  1.6
# 131  7.4  2.8  6.1  1.9
# 132  7.9  3.8  6.4  2.0
# 133  6.4  2.8  5.6  2.2
# 134  6.3  2.8  5.1  1.5
# 135  6.1  2.6  5.6  1.4
# 136  7.7  3.0  6.1  2.3
# 137  6.3  3.4  5.6  2.4
# ...

# %%
y_train = y[:100]

# %%
y_test = y[100:]

# %%
y_train
# Out:
# 1          Iris-setosa
# 2          Iris-setosa
# 3          Iris-setosa
# 4          Iris-setosa
# 5          Iris-setosa
#             ...
# 96     Iris-versicolor
# 97     Iris-versicolor
# 98     Iris-versicolor
# 99     Iris-versicolor
# 100    Iris-versicolor
# Name: labels, Length: 100, dtype: object

# %%
y_test
# Out:
# 101    Iris-virginica
# 102    Iris-virginica
# 103    Iris-virginica
# 104    Iris-virginica
# 105    Iris-virginica
# 106    Iris-virginica
# 107    Iris-virginica
# 108    Iris-virginica
# 109    Iris-virginica
# 110    Iris-virginica
# 111    Iris-virginica
# 112    Iris-virginica
# 113    Iris-virginica
# 114    Iris-virginica
# 115    Iris-virginica
# 116    Iris-virginica
# 117    Iris-virginica
# 118    Iris-virginica
# 119    Iris-virginica
# 120    Iris-virginica
# 121    Iris-virginica
# 122    Iris-virginica
# 123    Iris-virginica
# 124    Iris-virginica
# 125    Iris-virginica
# 126    Iris-virginica
# 127    Iris-virginica
# 128    Iris-virginica
# 129    Iris-virginica
# 130    Iris-virginica
# 131    Iris-virginica
# 132    Iris-virginica
# 133    Iris-virginica
# 134    Iris-virginica
# 135    Iris-virginica
# 136    Iris-virginica
# 137    Iris-virginica
# 138    Iris-virginica
# 139    Iris-virginica
# 140    Iris-virginica
# 141    Iris-virginica
# ...

# %%
# 2 make manual spliting using sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 30, random_state= 1)

# %%
x_train
# Out:
#       sl   sw   pl   pw
# 92   6.1  3.0  4.6  1.4
# 136  7.7  3.0  6.1  2.3
# 70   5.6  2.5  3.9  1.1
# 129  6.4  2.8  5.6  2.1
# 115  5.8  2.8  5.1  2.4
# ..   ...  ...  ...  ...
# 134  6.3  2.8  5.1  1.5
# 138  6.4  3.1  5.5  1.8
# 73   6.3  2.5  4.9  1.5
# 141  6.7  3.1  5.6  2.4
# 38   4.9  3.1  1.5  0.1
#
# [120 rows x 4 columns]

# %%
x_test
# Out:
#       sl   sw   pl   pw
# 15   5.8  4.0  1.2  0.2
# 99   5.1  2.5  3.0  1.1
# 76   6.6  3.0  4.4  1.4
# 17   5.4  3.9  1.3  0.4
# 132  7.9  3.8  6.4  2.0
# 57   6.3  3.3  4.7  1.6
# 142  6.9  3.1  5.1  2.3
# 45   5.1  3.8  1.9  0.4
# 30   4.7  3.2  1.6  0.2
# 121  6.9  3.2  5.7  2.3
# 95   5.6  2.7  4.2  1.3
# 6    5.4  3.9  1.7  0.4
# 103  7.1  3.0  5.9  2.1
# 52   6.4  3.2  4.5  1.5
# 79   6.0  2.9  4.5  1.5
# 43   4.4  3.2  1.3  0.2
# 93   5.8  2.6  4.0  1.2
# 67   5.6  3.0  4.5  1.5
# 32   5.4  3.4  1.5  0.4
# 36   5.0  3.2  1.2  0.2
# 91   5.5  2.6  4.4  1.2
# 85   5.4  3.0  4.5  1.5
# 78   6.7  3.0  5.0  1.7
# 41   5.0  3.5  1.3  0.3
# 126  7.2  3.2  6.0  1.8
# 100  5.7  2.8  4.1  1.3
# 34   5.5  4.2  1.4  0.2
# 20   5.1  3.8  1.5  0.3
# 74   6.1  2.8  4.7  1.2
# 147  6.3  2.5  5.0  1.9

# %%
y_train
# Out:
# 92     Iris-versicolor
# 136     Iris-virginica
# 70     Iris-versicolor
# 129     Iris-virginica
# 115     Iris-virginica
#             ...
# 134     Iris-virginica
# 138     Iris-virginica
# 73     Iris-versicolor
# 141     Iris-virginica
# 38         Iris-setosa
# Name: labels, Length: 120, dtype: object

# %%
y_test
# Out:
# 15         Iris-setosa
# 99     Iris-versicolor
# 76     Iris-versicolor
# 17         Iris-setosa
# 132     Iris-virginica
# 57     Iris-versicolor
# 142     Iris-virginica
# 45         Iris-setosa
# 30         Iris-setosa
# 121     Iris-virginica
# 95     Iris-versicolor
# 6          Iris-setosa
# 103     Iris-virginica
# 52     Iris-versicolor
# 79     Iris-versicolor
# 43         Iris-setosa
# 93     Iris-versicolor
# 67     Iris-versicolor
# 32         Iris-setosa
# 36         Iris-setosa
# 91     Iris-versicolor
# 85     Iris-versicolor
# 78     Iris-versicolor
# 41         Iris-setosa
# 126     Iris-virginica
# 100    Iris-versicolor
# 34         Iris-setosa
# 20         Iris-setosa
# 74     Iris-versicolor
# 147     Iris-virginica
# Name: labels, dtype: object
