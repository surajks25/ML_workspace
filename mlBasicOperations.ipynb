# %% [markdown]
# <a href="https://colab.research.google.com/github/surajks25/ML_workspace/blob/main/mlBasicOperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/Iris.csv",header=None)

# %%
data
# Out:
#        0              1             2              3             4  \
# 0     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1      1            5.1           3.5            1.4           0.2
# 2      2            4.9           3.0            1.4           0.2
# 3      3            4.7           3.2            1.3           0.2
# 4      4            4.6           3.1            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 146  146            6.7           3.0            5.2           2.3
# 147  147            6.3           2.5            5.0           1.9
# 148  148            6.5           3.0            5.2           2.0
# 149  149            6.2           3.4            5.4           2.3
# 150  150            5.9           3.0            5.1           1.8
#
#                   5
# 0           Species
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.columns
# Out:
# Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
data
# Out:
#        0              1             2              3             4  \
# 0     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1      1            5.1           3.5            1.4           0.2
# 2      2            4.9           3.0            1.4           0.2
# 3      3            4.7           3.2            1.3           0.2
# 4      4            4.6           3.1            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 146  146            6.7           3.0            5.2           2.3
# 147  147            6.3           2.5            5.0           1.9
# 148  148            6.5           3.0            5.2           2.0
# 149  149            6.2           3.4            5.4           2.3
# 150  150            5.9           3.0            5.1           1.8
#
#                   5
# 0           Species
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.head()
# Out:
#     0              1             2              3             4            5
# 0  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   1            5.1           3.5            1.4           0.2  Iris-setosa
# 2   2            4.9           3.0            1.4           0.2  Iris-setosa
# 3   3            4.7           3.2            1.3           0.2  Iris-setosa
# 4   4            4.6           3.1            1.5           0.2  Iris-setosa

# %%
data.columns
# Out:
# Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
data.columns = ['id','length','width','petallength','width','label']

# %%
data
# Out:
#       id         length         width    petallength         width  \
# 0     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1      1            5.1           3.5            1.4           0.2
# 2      2            4.9           3.0            1.4           0.2
# 3      3            4.7           3.2            1.3           0.2
# 4      4            4.6           3.1            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 146  146            6.7           3.0            5.2           2.3
# 147  147            6.3           2.5            5.0           1.9
# 148  148            6.5           3.0            5.2           2.0
# 149  149            6.2           3.4            5.4           2.3
# 150  150            5.9           3.0            5.1           1.8
#
#               label
# 0           Species
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data = data.drop(index=0)

# %%
data.head()
# Out:
#   id length width petallength width        label
# 1  1    5.1   3.5         1.4   0.2  Iris-setosa
# 2  2    4.9   3.0         1.4   0.2  Iris-setosa
# 3  3    4.7   3.2         1.3   0.2  Iris-setosa
# 4  4    4.6   3.1         1.5   0.2  Iris-setosa
# 5  5    5.0   3.6         1.4   0.2  Iris-setosa

# %%
data = data.drop(columns=["id"])

# %%
data.head()
# Out:
#   length width petallength width        label
# 1    5.1   3.5         1.4   0.2  Iris-setosa
# 2    4.9   3.0         1.4   0.2  Iris-setosa
# 3    4.7   3.2         1.3   0.2  Iris-setosa
# 4    4.6   3.1         1.5   0.2  Iris-setosa
# 5    5.0   3.6         1.4   0.2  Iris-setosa

# %%
data = data.rename(columns={
    "length": "sepal_length",
    "width": "sepal_width",
    "petallength": "petal_length",
    "label": "label"
})
data.head()
# Out:
#   sepal_length sepal_width petal_length sepal_width        label
# 1          5.1         3.5          1.4         0.2  Iris-setosa
# 2          4.9         3.0          1.4         0.2  Iris-setosa
# 3          4.7         3.2          1.3         0.2  Iris-setosa
# 4          4.6         3.1          1.5         0.2  Iris-setosa
# 5          5.0         3.6          1.4         0.2  Iris-setosa

# %%
data.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  sepal_width  label
# 1           False        False         False        False  False
# 2           False        False         False        False  False
# 3           False        False         False        False  False
# 4           False        False         False        False  False
# 5           False        False         False        False  False
# ..            ...          ...           ...          ...    ...
# 146         False        False         False        False  False
# 147         False        False         False        False  False
# 148         False        False         False        False  False
# 149         False        False         False        False  False
# 150         False        False         False        False  False
#
# [150 rows x 5 columns]

# %%
data.isna()
# Out:
#      sepal_length  sepal_width  petal_length  sepal_width  label
# 1           False        False         False        False  False
# 2           False        False         False        False  False
# 3           False        False         False        False  False
# 4           False        False         False        False  False
# 5           False        False         False        False  False
# ..            ...          ...           ...          ...    ...
# 146         False        False         False        False  False
# 147         False        False         False        False  False
# 148         False        False         False        False  False
# 149         False        False         False        False  False
# 150         False        False         False        False  False
#
# [150 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# sepal_width     0
# label           0
# dtype: int64

# %%
data.dropna()
# Out:
#     sepal_length sepal_width petal_length sepal_width           label
# 1            5.1         3.5          1.4         0.2     Iris-setosa
# 2            4.9         3.0          1.4         0.2     Iris-setosa
# 3            4.7         3.2          1.3         0.2     Iris-setosa
# 4            4.6         3.1          1.5         0.2     Iris-setosa
# 5            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 146          6.7         3.0          5.2         2.3  Iris-virginica
# 147          6.3         2.5          5.0         1.9  Iris-virginica
# 148          6.5         3.0          5.2         2.0  Iris-virginica
# 149          6.2         3.4          5.4         2.3  Iris-virginica
# 150          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#if 5 value is there in he database keep it as same database, other wise delete hole row
data.dropna(thresh=5)
# Out:
#     sepal_length sepal_width petal_length sepal_width           label
# 1            5.1         3.5          1.4         0.2     Iris-setosa
# 2            4.9         3.0          1.4         0.2     Iris-setosa
# 3            4.7         3.2          1.3         0.2     Iris-setosa
# 4            4.6         3.1          1.5         0.2     Iris-setosa
# 5            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 146          6.7         3.0          5.2         2.3  Iris-virginica
# 147          6.3         2.5          5.0         1.9  Iris-virginica
# 148          6.5         3.0          5.2         2.0  Iris-virginica
# 149          6.2         3.4          5.4         2.3  Iris-virginica
# 150          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]
