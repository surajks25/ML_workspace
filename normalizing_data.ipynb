# %% [markdown]
# <a href="https://colab.research.google.com/github/surajks25/ML_workspace/blob/main/normalizing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    [
        [25000,200,30.5],
        [18000,150,12.5],
        [9000,100,25.7],
        [40000,300,21.2]
    ],
    columns = ['A', 'B', 'C']
)

# %%
display(df)
# Out:
#        A    B     C
# 0  25000  200  30.5
# 1  18000  150  12.5
# 2   9000  100  25.7
# 3  40000  300  21.2

# %%
#visualiz the data for see the diff in the dataset
import matplotlib.pyplot as plt
df.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
#use the Maximum absolute scaling for normaliz data

# %%
df_copy = df.copy()

# %%
df_copy
# Out:
#        A    B     C
# 0  25000  200  30.5
# 1  18000  150  12.5
# 2   9000  100  25.7
# 3  40000  300  21.2

# %%
for col in df_copy.columns:
  df_copy[col] = df_copy[col] / df_copy[col].abs().max()

# %%
display(df_copy)
# Out:
#        A         B         C
# 0  0.625  0.666667  1.000000
# 1  0.450  0.500000  0.409836
# 2  0.225  0.333333  0.842623
# 3  1.000  1.000000  0.695082

# %%
df.abs().max() #function of this
# Out:
# A    40000.0
# B      300.0
# C       30.5
# dtype: float64

# %%
df_copy.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
#min max feature scaling
df_copy_minmax = df.copy()

# %%
df_copy_minmax
# Out:
#        A    B     C
# 0  25000  200  30.5
# 1  18000  150  12.5
# 2   9000  100  25.7
# 3  40000  300  21.2

# %%
for col in df_copy_minmax.columns:
    df_copy_minmax[col] = (df_copy_minmax[col] - df_copy_minmax[col].min()) / (df_copy_minmax[col].max() - df_copy_minmax[col].min())

# %%
display(df_copy_minmax)
# Out:
#           A     B         C
# 0  0.516129  0.50  1.000000
# 1  0.290323  0.25  0.000000
# 2  0.000000  0.00  0.733333
# 3  1.000000  1.00  0.483333

# %%
df_copy_minmax.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
#zscore
df_copy_zscore = df.copy()

# %%
df_copy_zscore
# Out:
#        A    B     C
# 0  25000  200  30.5
# 1  18000  150  12.5
# 2   9000  100  25.7
# 3  40000  300  21.2

# %%
for col in df_copy_zscore.columns:
  df_copy_zscore[col] = (df_copy_zscore[col] - df_copy_zscore[col].mean()) / df_copy_zscore[col].std()

# %%
display(df_copy_zscore)
# Out:
#           A         B         C
# 0  0.152795  0.146385  1.047946
# 1 -0.381987 -0.439155 -1.302587
# 2 -1.069565 -1.024695  0.421137
# 3  1.298757  1.317465 -0.166496

# %%
df_copy_zscore.plot(kind = "bar")
# Out:
# <Axes: >
