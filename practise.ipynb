# %% [markdown]
# <a href="https://colab.research.google.com/github/surajks25/ML_workspace/blob/main/practise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/iris2.csv")
df
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1            5.1           3.5            1.4           0.2
# 1    2            4.9           3.0            1.4           0.2
# 2    3            4.7           3.2            1.3           0.2
# 3    4            4.6           3.1            1.5           0.2
# 4    5            5.0           3.6            1.4           0.2
# 5    6            7.0           3.2            4.7           1.4
# 6    7            6.4           3.2            4.5           1.5
# 7    8            6.9           3.1            4.9           1.5
# 8    9            5.5           2.3            4.0           1.3
# 9   10            6.5           2.8            4.6           1.5
# 10  11            6.3           3.3            6.0           2.5
# 11  12            5.8           2.7            5.1           1.9
# 12  13            7.1           3.0            5.9           2.1
# ...

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#drop the id
df = df.drop("Id", axis=1)
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.drop(index = 0, inplace=True)

# %%
df
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0             5.1           3.5            1.4           0.2      Iris-setosa
# 1             4.9           3.0            1.4           0.2      Iris-setosa
# 2             4.7           3.2            1.3           0.2      Iris-setosa
# 3             4.6           3.1            1.5           0.2      Iris-setosa
# 4             5.0           3.6            1.4           0.2      Iris-setosa
# 5             7.0           3.2            4.7           1.4  Iris-versicolor
# 6             6.4           3.2            4.5           1.5  Iris-versicolor
# 7             6.9           3.1            4.9           1.5  Iris-versicolor
# 8             5.5           2.3            4.0           1.3  Iris-versicolor
# 9             6.5           2.8            4.6           1.5  Iris-versicolor
# 10            6.3           3.3            6.0           2.5   Iris-virginica
# ...

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 1            4.9           3.0            1.4           0.2      Iris-setosa
# 2            4.7           3.2            1.3           0.2      Iris-setosa
# 3            4.6           3.1            1.5           0.2      Iris-setosa
# 4            5.0           3.6            1.4           0.2      Iris-setosa
# 5            7.0           3.2            4.7           1.4  Iris-versicolor

# %%
df = df.rename(columns={
    "SepalLengthCm": "sl",
    "SepalWidthCm": "sw",
    "PetalLengthCm": "pl",
    "PetalWidthCm": "pw",
    "Species": "labels"
})
df.head()
# Out:
#     sl   sw   pl   pw           labels
# 1  4.9  3.0  1.4  0.2      Iris-setosa
# 2  4.7  3.2  1.3  0.2      Iris-setosa
# 3  4.6  3.1  1.5  0.2      Iris-setosa
# 4  5.0  3.6  1.4  0.2      Iris-setosa
# 5  7.0  3.2  4.7  1.4  Iris-versicolor

# %%
x = df[['sl','sw','pl','pw']]
y = df['labels']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
x_train.head()
# Out:
#      sl   sw   pl   pw
# 5   7.0  3.2  4.7  1.4
# 2   4.7  3.2  1.3  0.2
# 13  6.3  2.9  5.6  1.8
# 1   4.9  3.0  1.4  0.2
# 14  6.5  3.0  5.8  2.2

# %%
import matplotlib.pyplot as plt
df.plot(kind='bar')
plt.show()
